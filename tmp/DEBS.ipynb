# %%
import pandas as pd

# %%
from os import listdir
from os.path import isfile, join
debs_files = 'DEBS'
debs_files_dirty = [f for f in listdir(mypath) if isfile(join(mypath, f)) and 'dirty' in f]
debs_files_clean = [f for f in listdir(mypath) if isfile(join(mypath, f)) and 'clean' in f]

# %%
for i in debs_files_dirty[:1]:
    data_dirty = pd.read_csv(debs_files + '/' + )

# %%
data_dirty = pd.read_csv(debs_files + '/' + 'DEBS_dirty_0.csv')
data_clean = pd.read_csv(debs_files + '/' + 'DEBS_clean_0.csv')

# %%
data_dirty
# Out:
#                             medallion                      hack_license  \
# 0    07290D3599E7A0D62097A346EFCC1FB5  E7750A37CAB07D0DFF0AF7E3573AC141
# 1    22D70BF00EEB0ADC83BA8177BB861991  3FF2709163DE7036FCAA4E5A3324E4BF
# 2    0EC22AAF491A8BD91F279350C2B010FD  778C92B26AE78A9EBDF96B49C67E4007
# 3    1390FB380189DF6BBFDA4DC847CAD14F  BE317B986700F63C43438482792C8654
# 4    3B4129883A1D05BE89F2C929DE136281  7077F9FD5AD649AEACA4746B2537E3FA
# ..                                ...                               ...
# 434  8AD91402938128BE88812A92F89A76C0  632F6951F36191B8B3A0DB9311F1693A
# 435  348D6EB1395F30486361304582231889  B391B47E5CFAA2498247F34C5B8FB8E9
# 436  0A522ABFC595C8CA155690782639621E  6C244F5AA559CC18B2E60F1330EF7C37
# 437  942EDD26C4E3337133058C095AD23289  7EB4ADB170F6990F16A1ADC1806EC2AE
# 438  1D2CAE137C3B212056E1A03E0E981BCC  70B60316F490A0B3EE45BC1A3CA66BB1
#
#                    pickup_datetime               dropoff_datetime  \
# ...

# %%
data_clean
# Out:
#                             medallion                      hack_license  \
# 0    07290D3599E7A0D62097A346EFCC1FB5  E7750A37CAB07D0DFF0AF7E3573AC141
# 1    22D70BF00EEB0ADC83BA8177BB861991  3FF2709163DE7036FCAA4E5A3324E4BF
# 2    0EC22AAF491A8BD91F279350C2B010FD  778C92B26AE78A9EBDF96B49C67E4007
# 3    1390FB380189DF6BBFDA4DC847CAD14F  BE317B986700F63C43438482792C8654
# 4    3B4129883A1D05BE89F2C929DE136281  7077F9FD5AD649AEACA4746B2537E3FA
# ..                                ...                               ...
# 434  8AD91402938128BE88812A92F89A76C0  632F6951F36191B8B3A0DB9311F1693A
# 435  348D6EB1395F30486361304582231889  B391B47E5CFAA2498247F34C5B8FB8E9
# 436  0A522ABFC595C8CA155690782639621E  6C244F5AA559CC18B2E60F1330EF7C37
# 437  942EDD26C4E3337133058C095AD23289  7EB4ADB170F6990F16A1ADC1806EC2AE
# 438  1D2CAE137C3B212056E1A03E0E981BCC  70B60316F490A0B3EE45BC1A3CA66BB1
#
#                    pickup_datetime               dropoff_datetime  \
# ...
